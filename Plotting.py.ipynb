# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as mplot3d

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(range(3), range(3), range(3))

# %%
fig.show()
# Out:
# /home/sturm/.local/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
data = DataFr
